# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist[1]
# Out:
# 'hello'

# %%
import pandas
import numpy

# %% [markdown]
# # syntax error

# %%
print("python errors")
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={"1":"hello","2":"bye", '3':"python"}
mydictionnary['1']
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)
i+=1
# Out:
# Streaming output truncated to the last 5000 lines.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
# Out:
# 3

# %% [markdown]
# # TypeError

# %%
15+15
# Out:
# 30

# %% [markdown]
# # ValueError

# %%
str('python')
# Out:
# 'python'

# %% [markdown]
# # NameError

# %%
def python():
  print("w")

python
# Out:
# <function __main__.python()>

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/2
